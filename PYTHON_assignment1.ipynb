# %%
# ASSIGNMENT NO. 1
# DIFFERENT OPERATIONS ON DICTIONARY AND TUPLE DATA STRUCTURE

#LIST OPERATIONS 
print("LIST OPERATIONS")
student_list = ["shruti", "aanaya", "anushka", "akansha", "sanskruti"]
print("Original List:", student_list)
student_list.append("payal")
print("After Append:", student_list)
student_list.insert(1, "priya")
print("After Insert:", student_list)
student_list.remove("akansha")
print("After Remove:", student_list)
student_list.pop()
print("After Pop:", student_list)
student_list.sort()
print("After Sort:", student_list)


# TUPLE OPERATIONS 
print("\nTUPLE OPERATIONS")
student_tuple = ("atharva", "mohit", "Divya", "aayush", "sameer")
print("Original Tuple:", student_tuple)
print("Count of mohit:", student_tuple.count("mohit"))
print("Index of Divya:", student_tuple.index("Divya"))
student_tuple = student_tuple + ("atharva",)
print("After Adding Element:", student_tuple)
print("Sliced Tuple:", student_tuple[1:4])
print("Length of Tuple:", len(student_tuple))


# DICTIONARY OPERATIONS 
student_dict = {
    101: "shruti",
    102: "samprikta",
    103: "sanvi",
    104: "swanandi",
    105: "shubham"
}
print("\nDICTIONARY OPERATIONS")
print("Original Dictionary:", student_dict)
student_dict[106] = "priyanshi"
print("After Adding Key 106:", student_dict)
student_dict[101] = "priya"
print("After Updating Key 101:", student_dict)
student_dict.pop(102)
print("After Removing Key 102:", student_dict)
print("Keys:", student_dict.keys())
print("Values:", student_dict.values())
print("Items:", student_dict.items())
print("Value using get():", student_dict.get(103))
# Out:
# LIST OPERATIONS
# Original List: ['shruti', 'aanaya', 'anushka', 'akansha', 'sanskruti']
# After Append: ['shruti', 'aanaya', 'anushka', 'akansha', 'sanskruti', 'payal']
# After Insert: ['shruti', 'priya', 'aanaya', 'anushka', 'akansha', 'sanskruti', 'payal']
# After Remove: ['shruti', 'priya', 'aanaya', 'anushka', 'sanskruti', 'payal']
# After Pop: ['shruti', 'priya', 'aanaya', 'anushka', 'sanskruti']
# After Sort: ['aanaya', 'anushka', 'priya', 'sanskruti', 'shruti']
#
# TUPLE OPERATIONS
# Original Tuple: ('atharva', 'mohit', 'Divya', 'aayush', 'sameer')
# Count of mohit: 1
# Index of Divya: 2
# After Adding Element: ('atharva', 'mohit', 'Divya', 'aayush', 'sameer', 'atharva')
# Sliced Tuple: ('mohit', 'Divya', 'aayush')
# Length of Tuple: 6
#
# DICTIONARY OPERATIONS
# Original Dictionary: {101: 'shruti', 102: 'samprikta', 103: 'sanvi', 104: 'swanandi', 105: 'shubham'}
# ...
