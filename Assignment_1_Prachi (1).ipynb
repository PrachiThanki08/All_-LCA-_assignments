# %%
#Assignment 1: Stundent Data Management
students = {
    101: ("Shruti", "CSE", [85,90,88]),
    102: ("Shreya", "ECE", [78,82,80]),
    103: ("Samprikta", "AIDS", [91,89,94])
          }

print("Original student records:")
print(students)

#Adding a new student
students[104] = ("Atharva", "CSE", [76,81,79])
print("\nAfter adding a new student:")
print(students)

#Deleting a student
del students[102]
print("\nAfter deleting student 102:")
print(students)

# Updating a student's details
students[101] = ("Shruti", "AIDS", [88,92,90])
print("\nAfter updating student 101:")
print(students)

#displaying final records
print("\nFinal student records:")

for roll_number in students:
    print("Roll Number:", roll_number)
    print("Name:", students[roll_number][0])
    print("Branch:", students[roll_number][1])
    print ("Marks:", students[roll_number][2])
    print()
# Out:
# Original student records:
# {101: ('Shruti', 'CSE', [85, 90, 88]), 102: ('Shreya', 'ECE', [78, 82, 80]), 103: ('Samprikta', 'AIDS', [91, 89, 94])}
#
# After adding a new student:
# {101: ('Shruti', 'CSE', [85, 90, 88]), 102: ('Shreya', 'ECE', [78, 82, 80]), 103: ('Samprikta', 'AIDS', [91, 89, 94]), 104: ('Atharva', 'CSE', [76, 81, 79])}
#
# After deleting student 102:
# {101: ('Shruti', 'CSE', [85, 90, 88]), 103: ('Samprikta', 'AIDS', [91, 89, 94]), 104: ('Atharva', 'CSE', [76, 81, 79])}
#
# After updating student 101:
# {101: ('Shruti', 'AIDS', [88, 92, 90]), 103: ('Samprikta', 'AIDS', [91, 89, 94]), 104: ('Atharva', 'CSE', [76, 81, 79])}
#
# Final student records:
# Roll Number: 101
# Name: Shruti
# Branch: AIDS
# Marks: [88, 92, 90]
#
# Roll Number: 103
# Name: Samprikta
# Branch: AIDS
# Marks: [91, 89, 94]
#
# Roll Number: 104
# Name: Atharva
# Branch: CSE
# Marks: [76, 81, 79]
